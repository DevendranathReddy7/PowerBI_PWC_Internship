# %%
import pandas as pd #importing pands
import numpy as np #importing numpy
import matplotlib.pyplot as plt #importing plot library

# %%
ccd = pd.read_excel("C:\\Users\\devendra reddy\\Downloads\\01 Call-Center-Dataset.xlsx") # importing data

# %%
ccd
# Out:
#      Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0     ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1     ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2     ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3     ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4     ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
# ...      ...      ...         ...       ...                ...            ...
# 4995  ID4996      Jim  2021-03-31  16:37:55    Payment related              Y
# 4996  ID4997    Diane  2021-03-31  16:45:07    Payment related              Y
# 4997  ID4998    Diane  2021-03-31  16:53:46    Payment related              Y
# 4998  ID4999      Jim  2021-03-31  17:02:24          Streaming              Y
# 4999  ID5000    Diane  2021-03-31  17:39:50   Contract related              N
#
# ...

# %%
ccd['Speed of answer in seconds'] = ccd['Speed of answer in seconds'].fillna(ccd['Speed of answer in seconds'].mean()) # filling values with mean of repective columns

# %%
ccd[['Speed of answer in seconds','Satisfaction rating']] = ccd[['Speed of answer in seconds','Satisfaction rating']].fillna(ccd[['Speed of answer in seconds','Satisfaction rating']].mean())

# %%
ccd.head(7)
# Out:
#   Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0  ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1  ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2  ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3  ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4  ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
# 5  ID0006  Stewart  2021-01-01  10:00:29  Technical Support              N
# 6  ID0007    Diane  2021-01-01  10:22:05    Payment related              Y
#
#   Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating
# 0        Y                   109.00000        00:02:23             3.000000
# 1        N                    70.00000        00:04:02             3.000000
# 2        Y                    10.00000        00:02:11             3.000000
# ...

# %%
ccd = ccd.fillna(0) # replace NAN with 0

# %%
ccd.head(7) # gives first 7 rows in ccd
# Out:
#   Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0  ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1  ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2  ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3  ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4  ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
# 5  ID0006  Stewart  2021-01-01  10:00:29  Technical Support              N
# 6  ID0007    Diane  2021-01-01  10:22:05    Payment related              Y
#
#   Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating
# 0        Y                   109.00000        00:02:23             3.000000
# 1        N                    70.00000        00:04:02             3.000000
# 2        Y                    10.00000        00:02:11             3.000000
# ...

# %%
ccd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Call Id                     5000 non-null   object
#  1   Agent                       5000 non-null   object
#  2   Date                        5000 non-null   object
#  3   Time                        5000 non-null   object
#  4   Topic                       5000 non-null   object
#  5   Answered (Y/N)              5000 non-null   object
#  6   Resolved                    5000 non-null   object
#  7   Speed of answer in seconds  5000 non-null   float64
#  8   AvgTalkDuration             5000 non-null   object
#  9   Satisfaction rating         5000 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 390.8+ KB

# %%
ccd.describe() #gives aggregate functions for numeric data type rows only
# Out:
#        Speed of answer in seconds  Satisfaction rating
# count                 5000.000000          5000.000000
# mean                    67.520720             3.403552
# std                     30.247806             1.091511
# min                     10.000000             1.000000
# 25%                     45.000000             3.000000
# 50%                     67.520720             3.403552
# 75%                     90.000000             4.000000
# max                    125.000000             5.000000

# %%
ccd.duplicated() #retrives duplicates value as True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
ccd.corr() #correlations
# Out:
#                             Speed of answer in seconds  Satisfaction rating
# Speed of answer in seconds                    1.000000             0.000952
# Satisfaction rating                           0.000952             1.000000

# %%
ccd.plot(kind='kde', x='Resolved', y='Speed of answer in seconds' )
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ccd.plot(kind='bar', x='Satisfaction rating', y='Speed of answer in seconds')
# Out:
# <AxesSubplot:xlabel='Satisfaction rating'>

# %%
ccd.to_excel('C:\\Users\\devendra reddy\\Downloads\\CallCenterDataset.xlsx')
